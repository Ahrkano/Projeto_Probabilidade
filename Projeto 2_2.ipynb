# %% [markdown]
# <img width="300" alt="creating a repo" src="https://raw.githubusercontent.com/Ahrkano/Projeto_Probabilidade/master/imagens/logo_UFRN.jpg">
# <img width="200" alt="creating a repo" src="https://raw.githubusercontent.com/Ahrkano/Projeto_Probabilidade/master/imagens/logo_imd.png">

# %% [markdown]
# # Introdução
# Este estudo tem por objetivo estabelecer uma correlação entre a taxa de aprovação/reprovação dos docentes do **Instituto Metrópole Digital** e as notas médias de suas avaliações como educadores.

# %% [markdown]
# # Base de dados
#
# O Portal de Dados Abertos da UFRN tem como objetivo disponibilizar para toda a comunidade dados e informações públicas da Instituição, que podem ser usadas no desenvolvimento de aplicativos e ações.
# Desse modo, todos os dados utilizados neste estudo podem ser verificados em : http://dados.ufrn.br/group/ensino

# %% [markdown]
# # Filtragem de dados
#
# Tendo em vista a grande quantidade de informações disponibilizadas e as pequenas falhas encontradas em determinados pontos, uma filtragem dos dados se faz necessária.
# Desse modo, algumas informações serão removidas do dataframe ao passo que outras serão mescladas.

# %% [markdown]
# # Importando bibliotecas

# %%
# importando as bibliotecas necessárias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Importando dados

# %%
#Avaliações de docência
nota_docente_url = 'https://bit.ly/2IqonoW'

#Componentes curriculares presenciais
disciplinas_url = 'http://bit.do/componentes_curriculares_ufrn'

#Turmas de 2015.1 até 2017.1
turmas_2017_1_url = 'https://bit.ly/2wn1AFI'
turmas_2016_2_url = 'https://bit.ly/2I14eGu'
turmas_2016_1_url = 'https://bit.ly/2IoXKAG'
turmas_2015_2_url = 'https://bit.ly/2wrhMpw'
turmas_2015_1_url = 'https://bit.ly/2IaxFC5'

#Matrículas em componentes de 2015.1 até 2017.1
notas_2017_1_url = 'https://bit.ly/2KMoTvS'
notas_2016_2_url = 'https://bit.ly/2rup6Ma'
notas_2016_1_url = 'https://bit.ly/2K7oy5w'
notas_2015_2_url = 'https://bit.ly/2rvknKb'
notas_2015_1_url = 'https://bit.ly/2I8YfeM'

#Docentes da ufrn atualizado em 2018
docentes_url = 'http://bit.do/docentes_ufrn_2018'

#Dataframe das turmas
turmas_2017_1 = pd.read_csv(turmas_2017_1_url, sep=';')
turmas_2016_2 = pd.read_csv(turmas_2016_2_url, sep=';')
turmas_2016_1 = pd.read_csv(turmas_2016_1_url, sep=';')
turmas_2015_2 = pd.read_csv(turmas_2015_2_url, sep=';')
turmas_2015_1 = pd.read_csv(turmas_2015_1_url, sep=';')

#Dataframe das matriculas em componentes
notas_2017_1 = pd.read_csv(notas_2017_1_url, sep=';')
notas_2016_2 = pd.read_csv(notas_2016_2_url, sep=';')
notas_2016_1 = pd.read_csv(notas_2016_1_url, sep=';')
notas_2015_2 = pd.read_csv(notas_2015_2_url, sep=';')
notas_2015_1 = pd.read_csv(notas_2015_1_url, sep=';')


#Dataframe dos componentes curriculares presenciais
#realizado um filtro apenas por colunas mais importantes
disciplinas = pd.read_csv(disciplinas_url, sep=';', 
                          usecols=["id_componente","codigo","nivel","nome","unidade_responsavel"])

#Dataframe da avaliação dos docentes
#filtrando notas dos docentes
nota_docente = pd.read_csv(nota_docente_url, sep=';',
                           usecols=["id_docente", "nome_docente", "id_turma", "ano", 
                                    "autoavaliacao_aluno_media", "atuacao_profissional_media", 
                                    "postura_profissional_media" ])
#Dataframe de docentes da ufrn
docentes = pd.read_csv(docentes_url, sep=';')

# %% [markdown]
# # Preparação e Limpeza dos dados

# %% [markdown]
# ### Filtrando Dataframe Turmas

# %%
#selecionando apenas as colunas necessárias
turmas_cols = ['id_turma', 'codigo_turma', 'id_docente_interno','id_componente_curricular', 'nivel_ensino',
               'local', 'ano', 'periodo', 'descricao_horario',  'capacidade_aluno', 'tipo',
               'data_consolidacao',  'situacao_turma', 'modalidade_participantes']


turmas_2015_1 = turmas_2015_1[turmas_cols]
turmas_2015_2 = turmas_2015_2[turmas_cols]
turmas_2016_1 = turmas_2015_1[turmas_cols]
turmas_2016_2 = turmas_2015_2[turmas_cols]
turmas_2017_1 = turmas_2015_1[turmas_cols]

#concatenando verticalmente todas as turmas em um so dataframe
frames = [turmas_2015_1, turmas_2015_2, turmas_2016_1, turmas_2016_2, turmas_2017_1]
turmas_total = pd.concat(frames)

# Adaptando o dataframe turma e disciplinas para o merge
# Esse procedimento é necessário pois o dataframe turma está codificado com ids
# A coluna id_componente precisa ser a mesma em ambos os dataframes
turmas_total.rename(columns={'id_componente_curricular': 'id_componente'}, inplace=True)

# id_componente em ambos os dataframes precisam ser do mesmo tipo
turmas_total.id_componente = turmas_total.id_componente.astype(str)

# investigando os dados
turmas_total.head()
# Out:
#    id_turma codigo_turma  id_docente_interno id_componente nivel_ensino  \
# 0   1217099           01             18225.0         52922   LATO SENSU
# 1   1217100           01             18695.0         52921   LATO SENSU
# 2   1217101           01           5753068.0         52925   LATO SENSU
# 3   1217102           01                 NaN         52920   LATO SENSU
# 4   1217102           01                 NaN         52920   LATO SENSU
#
#                                  local   ano  periodo  \
# 0  Depto. de Oceanografia e Limnologia  2015        1
# 1  Depto. de Oceanografia e Limnologia  2015        1
# 2  Depto. de Oceanografia e Limnologia  2015        1
# 3  Depto. de Oceanografia e Limnologia  2015        1
# 4  Depto. de Oceanografia e Limnologia  2015        1
#
#                           descricao_horario  capacidade_aluno     tipo  \
# 0                                 23456T234              26.0  REGULAR
# 1  345T2345 6T234 (14/04/2015 - 17/04/2015)              26.0  REGULAR
# 2                              23456T123456              26.0  REGULAR
# 3                              23456T123456              26.0  REGULAR
# 4                              23456T123456              26.0  REGULAR
#
#          data_consolidacao situacao_turma modalidade_participantes
# 0  2015-06-01 12:53:14.625    CONSOLIDADA               Presencial
# 1  2015-10-08 16:19:21.901    CONSOLIDADA               Presencial
# 2  2015-06-01 12:50:38.962    CONSOLIDADA               Presencial
# 3  2015-08-26 11:48:34.146    CONSOLIDADA               Presencial
# 4  2015-08-26 11:48:34.146    CONSOLIDADA               Presencial

# %% [markdown]
# ### Filtrando Dataframe Matrículas

# %%
#selecionando apenas as colunas necessárias
notas_cols = ['id_turma', 'discente', 'id_curso', 'unidade', 'nota', 'media_final', 'descricao']

notas_2015_1 = notas_2015_1[notas_cols]
notas_2015_2 = notas_2015_2[notas_cols]
notas_2016_1 = notas_2016_1[notas_cols]
notas_2016_2 = notas_2016_2[notas_cols]
notas_2017_1 = notas_2017_1[notas_cols]

#concatenando verticalmente
frames = [notas_2015_1, notas_2015_2, notas_2016_1, notas_2016_2, notas_2017_1]
notas_total = pd.concat(frames)

# Limpando o dataframe disciplinas com linhas desnecessárias
disciplinas.dropna(inplace=True)
disciplinas = disciplinas[~disciplinas.id_componente.duplicated()]

# investigando os dados
notas_total.head()
# Out:
#    id_turma                          discente     id_curso  unidade  nota  \
# 0  57562481  8833c0e056f90497742882bfcc81b685  100300443.0      2.0   0.0
# 1  57562481  8833c0e056f90497742882bfcc81b685  100300443.0      3.0   0.0
# 2  57562481  7a0a661326418111f7d17aab098757aa  100300443.0      1.0   8.9
# 3  57562481  7a0a661326418111f7d17aab098757aa  100300443.0      2.0   8.9
# 4  57562481  7a0a661326418111f7d17aab098757aa  100300443.0      3.0   8.9
#
#    media_final  descricao
# 0          0.0  REPROVADO
# 1          0.0  REPROVADO
# 2          8.9   APROVADO
# 3          8.9   APROVADO
# 4          8.9   APROVADO

# %% [markdown]
# ### Realizando mesclagem de colunas

# %%
# Fazendo um merge entre o dataframe turmas e disciplinas utilizando como base a coluna id_componente
# https://pandas.pydata.org/pandas-docs/stable/merging.html
colunas = ["id_turma","id_docente_interno","codigo","nivel_ensino","nome","unidade_responsavel",
          "situacao_turma","capacidade_aluno","descricao_horario", "ano", "periodo"]

# merge os dois dataframes utilizando como base a coluna id_componente
merge_turmas_disciplinas = pd.merge(turmas_total, disciplinas, on='id_componente')[colunas]

merge_turmas_disciplinas.dropna(inplace=True)

merge_turmas_disciplinas.drop_duplicates(subset='id_turma', keep='first', inplace=True)

# investigando os dados
merge_turmas_disciplinas.head()
# Out:
#     id_turma  id_docente_interno   codigo nivel_ensino  \
# 0    1217099             18225.0  DOL0009   LATO SENSU
# 3    1217100             18695.0  DOL0008   LATO SENSU
# 4   57573036           5753068.0  DOL0008   LATO SENSU
# 8    1217101           5753068.0  DOL0012   LATO SENSU
# 17   1237217             26152.0  DOD1421   LATO SENSU
#
#                                                  nome  \
# 0            Seminário de Simulação (Estudos de caso)
# 3   : Seminário sobre Políticas Públicas para o De...
# 4   : Seminário sobre Políticas Públicas para o De...
# 8                   Gestão Integrada da Zona Costeira
# 17                                         CARIOLOGIA
#
#                           unidade_responsavel situacao_turma  \
# 0   DEPARTAMENTO DE OCEANOGRAFIA E LIMNOLOGIA    CONSOLIDADA
# 3   DEPARTAMENTO DE OCEANOGRAFIA E LIMNOLOGIA    CONSOLIDADA
# 4   DEPARTAMENTO DE OCEANOGRAFIA E LIMNOLOGIA    CONSOLIDADA
# 8   DEPARTAMENTO DE OCEANOGRAFIA E LIMNOLOGIA    CONSOLIDADA
# 17                DEPARTAMENTO DE ODONTOLOGIA    CONSOLIDADA
#
#     capacidade_aluno                         descricao_horario   ano  periodo
# 0               26.0                                 23456T234  2015        1
# 3               26.0  345T2345 6T234 (14/04/2015 - 17/04/2015)  2015        1
# 4                2.0                                     56M12  2015        2
# 8               26.0                              23456T123456  2015        1
# 17              12.0                                    6T2345  2015        1

# %% [markdown]
# ### Filtrando dados relativos ao IMD

# %%
# filtrando as turmas com código IMD
turmas_total = merge_turmas_disciplinas[merge_turmas_disciplinas.codigo.str.contains("IMD")]

# utilizar apenas disciplinas com código "CONSOLIDADA"
turmas_total = turmas_total[turmas_total.situacao_turma == 'CONSOLIDADA']

# Adaptar o nome da coluna id_docente_interno para id_servidor
turmas_total.rename(columns={'id_docente_interno': 'id_servidor'}, inplace=True)

turmas_total.capacidade_aluno = turmas_total.capacidade_aluno.astype(np.int64)

# Adaptar os tipos de dados em turmas para o merge com o dataframe docentes
turmas_total.id_servidor = turmas_total.id_servidor.astype(np.int64)

# merge dos dataframes  turmas_imd e docentes utilizando como base a coluna id_servidor
colunas = ["id_turma", "codigo", "nivel_ensino", "nome_y", "codigo", "nivel_ensino",
          "nome_x","capacidade_aluno", "descricao_horario"]

turmas_nomesprof = pd.merge(turmas_total, docentes, on='id_servidor')[colunas]

# investigando os dados
turmas_nomesprof.head()
# Out:
#    id_turma   codigo nivel_ensino                         nome_y   codigo  \
# 0   1239374  IMD0019    GRADUAÇÃO  CHARLES ANDRYE GALVAO MADEIRA  IMD0019
# 1   1239381  IMD0019    GRADUAÇÃO  CHARLES ANDRYE GALVAO MADEIRA  IMD0019
# 2  57571383  IMD0030    GRADUAÇÃO  CHARLES ANDRYE GALVAO MADEIRA  IMD0030
# 3   1239554  IMD0101    GRADUAÇÃO  CHARLES ANDRYE GALVAO MADEIRA  IMD0101
# 4  57565081  IMD0522    GRADUAÇÃO  CHARLES ANDRYE GALVAO MADEIRA  IMD0522
#
#   nivel_ensino                                            nome_x  \
# 0    GRADUAÇÃO        RESOLUÇÃO DE PROBLEMAS MATEMÁTICOS PARA TI
# 1    GRADUAÇÃO        RESOLUÇÃO DE PROBLEMAS MATEMÁTICOS PARA TI
# 2    GRADUAÇÃO                        LINGUAGEM DE PROGRAMAÇÃO I
# 3    GRADUAÇÃO  TÓPICOS ESPECIAIS EM TECNOLOGIA DA INFORMAÇÃO II
# 4    GRADUAÇÃO         JOGOS DIGITAIS COMO FERRAMENTA PEDAGÓGICA
#
#    capacidade_aluno                   descricao_horario
# 0                67  236M1234 (02/02/2015 - 20/06/2015)
# 1                66  236M1234 (02/02/2015 - 20/06/2015)
# 2                40     35M56 (27/07/2015 - 19/12/2015)
# 3                40    6M3456 (02/02/2015 - 20/06/2015)
# 4                60     35T56 (27/07/2015 - 19/12/2015)

# %% [markdown]
# ### Relacionando avaliações de docentes aos dados das turmas

# %%
# Adaptar o nome da coluna nome_y para nome_docente
turmas_nomesprof.rename(columns={'nome_y': 'nome_docente'}, inplace=True)

# merge dos dataframes  turmas_nomesprof e nota_docente utilizando como base as coluna id_turma e nome_docente
avaliacao_turma = pd.merge(turmas_nomesprof, nota_docente, on=['id_turma', 'nome_docente'])

# investigando os dados
avaliacao_turma.head()
# Out:
#    id_turma   codigo nivel_ensino                   nome_docente   codigo  \
# 0   1239374  IMD0019    GRADUAÇÃO  CHARLES ANDRYE GALVAO MADEIRA  IMD0019
# 1   1239381  IMD0019    GRADUAÇÃO  CHARLES ANDRYE GALVAO MADEIRA  IMD0019
# 2  57571383  IMD0030    GRADUAÇÃO  CHARLES ANDRYE GALVAO MADEIRA  IMD0030
# 3   1239554  IMD0101    GRADUAÇÃO  CHARLES ANDRYE GALVAO MADEIRA  IMD0101
# 4  57565081  IMD0522    GRADUAÇÃO  CHARLES ANDRYE GALVAO MADEIRA  IMD0522
#
#   nivel_ensino                                            nome_x  \
# 0    GRADUAÇÃO        RESOLUÇÃO DE PROBLEMAS MATEMÁTICOS PARA TI
# 1    GRADUAÇÃO        RESOLUÇÃO DE PROBLEMAS MATEMÁTICOS PARA TI
# 2    GRADUAÇÃO                        LINGUAGEM DE PROGRAMAÇÃO I
# 3    GRADUAÇÃO  TÓPICOS ESPECIAIS EM TECNOLOGIA DA INFORMAÇÃO II
# 4    GRADUAÇÃO         JOGOS DIGITAIS COMO FERRAMENTA PEDAGÓGICA
#
#    capacidade_aluno                   descricao_horario  id_docente   ano  \
# 0                67  236M1234 (02/02/2015 - 20/06/2015)     5756386  2015
# 1                66  236M1234 (02/02/2015 - 20/06/2015)     5756386  2015
# 2                40     35M56 (27/07/2015 - 19/12/2015)     5756386  2015
# 3                40    6M3456 (02/02/2015 - 20/06/2015)     5756386  2015
# 4                60     35T56 (27/07/2015 - 19/12/2015)     5756386  2015
#
#    postura_profissional_media  atuacao_profissional_media  \
# 0                        9.58                        9.04
# 1                        9.85                        9.37
# 2                        9.79                        8.73
# 3                        9.70                        9.08
# 4                        9.47                        8.33
#
#    autoavaliacao_aluno_media
# 0                       7.47
# 1                       8.32
# 2                       7.88
# 3                       8.69
# 4                       8.55

# %% [markdown]
# ### Anexando porcentagem de aprovação por turma

# %%
# filtrar apenas as turmas do IMD
notas_imd = notas_total[notas_total.id_turma.isin(turmas_nomesprof.id_turma)]

# merge entre os dataframes notas_imd e turmas_imd_nomesprof utilizando como referencia id_turma
notas_imd_merge = pd.merge(notas_imd, turmas_nomesprof, on='id_turma')

# removendo discentes duplicados (notas unidades 1, 2, 3)
notas_imd_merge.drop_duplicates(subset=['id_turma', 'discente', 'id_curso'], keep='first', inplace=True)
notas_imd_merge.dropna(axis=1, inplace=True)
notas_imd_merge.head()
# Out:
#    id_turma                          discente  descricao   codigo  \
# 0   1239422  bcd9e4d861acc00fac216bbe953c63b8   EXCLUIDA  IMD0040
# 1   1239422  266360870439b157a5313fb03a907704   EXCLUIDA  IMD0040
# 5   1239422  3a3517f48b6be60b7f3a037b5903a1ce   EXCLUIDA  IMD0040
# 6   1239422  5dac5cab88de4928bbc3095150f768ff   EXCLUIDA  IMD0040
# 7   1239422  71ded068ae396ef3bb21c15219c4906b  CANCELADO  IMD0040
#
#   nivel_ensino             nome_docente   codigo nivel_ensino  \
# 0    GRADUAÇÃO  CARLOS EDUARDO DA SILVA  IMD0040    GRADUAÇÃO
# 1    GRADUAÇÃO  CARLOS EDUARDO DA SILVA  IMD0040    GRADUAÇÃO
# 5    GRADUAÇÃO  CARLOS EDUARDO DA SILVA  IMD0040    GRADUAÇÃO
# 6    GRADUAÇÃO  CARLOS EDUARDO DA SILVA  IMD0040    GRADUAÇÃO
# 7    GRADUAÇÃO  CARLOS EDUARDO DA SILVA  IMD0040    GRADUAÇÃO
#
#                         nome_x  capacidade_aluno  \
# 0  LINGUAGEM DE PROGRAMAÇÃO II                30
# 1  LINGUAGEM DE PROGRAMAÇÃO II                30
# 5  LINGUAGEM DE PROGRAMAÇÃO II                30
# 6  LINGUAGEM DE PROGRAMAÇÃO II                30
# 7  LINGUAGEM DE PROGRAMAÇÃO II                30
#
#                  descricao_horario
# 0  24N12 (02/02/2015 - 20/06/2015)
# 1  24N12 (02/02/2015 - 20/06/2015)
# 5  24N12 (02/02/2015 - 20/06/2015)
# 6  24N12 (02/02/2015 - 20/06/2015)
# 7  24N12 (02/02/2015 - 20/06/2015)

# %%
notas_imd_merge.pivot_table(index=["descricao","id_turma","nome_x"], values="codigo", aggfunc="count")
# Out:
#                                                                        codigo  \
# descricao id_turma nome_x
# APROVADO  1239374  RESOLUÇÃO DE PROBLEMAS MATEMÁTICOS PARA TI              18
#           1239381  RESOLUÇÃO DE PROBLEMAS MATEMÁTICOS PARA TI              13
#           1239386  RESOLUÇÃO DE PROBLEMAS MATEMÁTICOS PARA TI              15
#           1239388  RESOLUÇÃO DE PROBLEMAS MATEMÁTICOS PARA TI              15
#           1239395  PRÁTICAS DE LEITURA EM INGLÊS                           18
#           1239396  PRÁTICAS DE LEITURA EM INGLÊS                           17
#           1239397  PRÁTICAS DE LEITURA EM INGLÊS                           19
#           1239398  PRÁTICAS DE LEITURA EM INGLÊS                           12
#           1239405  INTRODUÇÃO ÀS TÉCNICAS DE PROGRAMAÇÃO                    3
#           1239406  INTRODUÇÃO ÀS TÉCNICAS DE PROGRAMAÇÃO                   10
#           1239407  ESTRUTURA DE DADOS BÁSICAS I                             5
#           1239408  ESTRUTURA DE DADOS BÁSICAS I                             7
#           1239409  ESTRUTURA DE DADOS BÁSICAS I                             8
#           1239410  LINGUAGEM DE PROGRAMAÇÃO I                               5
#           1239411  LINGUAGEM DE PROGRAMAÇÃO I                               6
#           1239412  PROBABILIDADE                                            2
#           1239413  PROBABILIDADE                                            4
#           1239415  CÁLCULO DIFERENCIAL E INTEGRAL I                         1
#           1239416  VETORES E GEOMETRIA ANALÍTICA                            8
#           1239417  VETORES E GEOMETRIA ANALÍTICA                            6
#           1239418  ESTRUTURAS DE DADOS BÁSICAS II                           3
#           1239419  ESTRUTURAS DE DADOS BÁSICAS II                           5
#           1239420  LINGUAGEM DE PROGRAMAÇÃO II                             10
#           1239422  LINGUAGEM DE PROGRAMAÇÃO II                              1
#           1239516  PRÁTICAS DE TÉCNICAS DE PROGRAMAÇÃO                      8
#           1239519  PRÁTICAS DE TÉCNICAS DE PROGRAMAÇÃO                      2
#           1239521  PRÁTICAS DE TÉCNICAS DE PROGRAMAÇÃO                      8
#           1239522  PRÁTICAS DE TÉCNICAS DE PROGRAMAÇÃO                      5
#           1239523  TECNOLOGIA DA INFORMAÇÃO E SOCIEDADE                    39
#           1239524  TECNOLOGIA DA INFORMAÇÃO E SOCIEDADE                    50
# ...                                                                       ...
# TRANCADO  57564847 CÁLCULO DIFERENCIAL E INTEGRAL I                         2
#           57564850 PRÁTICAS DE LEITURA E ESCRITA EM PORTUGUÊS II            1
#           57564851 PRÁTICAS DE LEITURA E ESCRITA EM PORTUGUÊS II            3
#           57564855 FUNDAMENTOS MATEMÁTICOS DA COMPUTAÇÃO II                 1
#           57564856 FUNDAMENTOS MATEMÁTICOS DA COMPUTAÇÃO I                  2
#           57564857 FUNDAMENTOS MATEMÁTICOS DA COMPUTAÇÃO I                  2
#           57564858 FUNDAMENTOS MATEMÁTICOS DA COMPUTAÇÃO II                 2
#           57564860 LINGUAGEM DE PROGRAMAÇÃO I                               2
#           57564862 LINGUAGEM DE PROGRAMAÇÃO I                               2
#           57564863 ESTRUTURA DE DADOS BÁSICAS I                             3
#           57564864 LINGUAGEM DE PROGRAMAÇÃO I                               4
#           57564865 ESTRUTURA DE DADOS BÁSICAS I                             4
#           57564866 PRÁTICAS DE LEITURA E ESCRITA EM INGLÊS                  4
#           57564869 VETORES E GEOMETRIA ANALÍTICA                            3
#           57564870 INTRODUÇÃO A SISTEMAS OPERACIONAIS                       3
#           57564872 REDES DE COMPUTADORES                                    1
#           57564873 TECNOLOGIAS EDUCACIONAIS                                 2
#           57564876 TÓPICOS ESPECIAIS EM INFORMÁTICA EDUCACIONAL I           6
#           57564877 SISTEMAS COLABORATIVOS DE APOIO À APRENDIZAGEM           2
#           57565061 DESENVOLVIMENTO DE SISTEMAS WEB II                       1
#           57565081 JOGOS DIGITAIS COMO FERRAMENTA PEDAGÓGICA                2
#           57565140 PROCESSO DE DESENVOLVIMENTO DE SOFTWARE EDUCACI...       2
#           57565145 LEVANTAMENTO E MODELAGEM DE REQUISITOS                   2
#           57565146 ACESSIBILIDADE DIGITAL                                   3
#           57565220 PRÁTICAS DE LEITURA EM INGLÊS                            4
#           57565222 RESOLUÇÃO DE PROBLEMAS MATEMÁTICOS PARA TI               3
#           57565224 RESOLUÇÃO DE PROBLEMAS MATEMÁTICOS PARA TI               1
#           57568130 TÓPICOS ESPECIAIS EM TECNOLOGIA DA INFORMAÇÃO IV         1
#           57568131 TÓPICOS ESPECIAIS EM TECNOLOGIA DA INFORMAÇÃO V          2
#           57572025 PROTOCOLO E SERVIÇOS DE INTERNET                         1
#
#                                                                        codigo
# descricao id_turma nome_x
# APROVADO  1239374  RESOLUÇÃO DE PROBLEMAS MATEMÁTICOS PARA TI              18
#           1239381  RESOLUÇÃO DE PROBLEMAS MATEMÁTICOS PARA TI              13
#           1239386  RESOLUÇÃO DE PROBLEMAS MATEMÁTICOS PARA TI              15
#           1239388  RESOLUÇÃO DE PROBLEMAS MATEMÁTICOS PARA TI              15
#           1239395  PRÁTICAS DE LEITURA EM INGLÊS                           18
#           1239396  PRÁTICAS DE LEITURA EM INGLÊS                           17
#           1239397  PRÁTICAS DE LEITURA EM INGLÊS                           19
#           1239398  PRÁTICAS DE LEITURA EM INGLÊS                           12
#           1239405  INTRODUÇÃO ÀS TÉCNICAS DE PROGRAMAÇÃO                    3
#           1239406  INTRODUÇÃO ÀS TÉCNICAS DE PROGRAMAÇÃO                   10
#           1239407  ESTRUTURA DE DADOS BÁSICAS I                             5
#           1239408  ESTRUTURA DE DADOS BÁSICAS I                             7
#           1239409  ESTRUTURA DE DADOS BÁSICAS I                             8
#           1239410  LINGUAGEM DE PROGRAMAÇÃO I                               5
#           1239411  LINGUAGEM DE PROGRAMAÇÃO I                               6
#           1239412  PROBABILIDADE                                            2
#           1239413  PROBABILIDADE                                            4
#           1239415  CÁLCULO DIFERENCIAL E INTEGRAL I                         1
#           1239416  VETORES E GEOMETRIA ANALÍTICA                            8
#           1239417  VETORES E GEOMETRIA ANALÍTICA                            6
#           1239418  ESTRUTURAS DE DADOS BÁSICAS II                           3
#           1239419  ESTRUTURAS DE DADOS BÁSICAS II                           5
#           1239420  LINGUAGEM DE PROGRAMAÇÃO II                             10
#           1239422  LINGUAGEM DE PROGRAMAÇÃO II                              1
#           1239516  PRÁTICAS DE TÉCNICAS DE PROGRAMAÇÃO                      8
#           1239519  PRÁTICAS DE TÉCNICAS DE PROGRAMAÇÃO                      2
#           1239521  PRÁTICAS DE TÉCNICAS DE PROGRAMAÇÃO                      8
#           1239522  PRÁTICAS DE TÉCNICAS DE PROGRAMAÇÃO                      5
#           1239523  TECNOLOGIA DA INFORMAÇÃO E SOCIEDADE                    39
#           1239524  TECNOLOGIA DA INFORMAÇÃO E SOCIEDADE                    50
# ...                                                                       ...
# TRANCADO  57564847 CÁLCULO DIFERENCIAL E INTEGRAL I                         2
#           57564850 PRÁTICAS DE LEITURA E ESCRITA EM PORTUGUÊS II            1
#           57564851 PRÁTICAS DE LEITURA E ESCRITA EM PORTUGUÊS II            3
#           57564855 FUNDAMENTOS MATEMÁTICOS DA COMPUTAÇÃO II                 1
#           57564856 FUNDAMENTOS MATEMÁTICOS DA COMPUTAÇÃO I                  2
#           57564857 FUNDAMENTOS MATEMÁTICOS DA COMPUTAÇÃO I                  2
#           57564858 FUNDAMENTOS MATEMÁTICOS DA COMPUTAÇÃO II                 2
#           57564860 LINGUAGEM DE PROGRAMAÇÃO I                               2
#           57564862 LINGUAGEM DE PROGRAMAÇÃO I                               2
#           57564863 ESTRUTURA DE DADOS BÁSICAS I                             3
#           57564864 LINGUAGEM DE PROGRAMAÇÃO I                               4
#           57564865 ESTRUTURA DE DADOS BÁSICAS I                             4
#           57564866 PRÁTICAS DE LEITURA E ESCRITA EM INGLÊS                  4
#           57564869 VETORES E GEOMETRIA ANALÍTICA                            3
#           57564870 INTRODUÇÃO A SISTEMAS OPERACIONAIS                       3
#           57564872 REDES DE COMPUTADORES                                    1
#           57564873 TECNOLOGIAS EDUCACIONAIS                                 2
#           57564876 TÓPICOS ESPECIAIS EM INFORMÁTICA EDUCACIONAL I           6
#           57564877 SISTEMAS COLABORATIVOS DE APOIO À APRENDIZAGEM           2
#           57565061 DESENVOLVIMENTO DE SISTEMAS WEB II                       1
#           57565081 JOGOS DIGITAIS COMO FERRAMENTA PEDAGÓGICA                2
#           57565140 PROCESSO DE DESENVOLVIMENTO DE SOFTWARE EDUCACI...       2
#           57565145 LEVANTAMENTO E MODELAGEM DE REQUISITOS                   2
#           57565146 ACESSIBILIDADE DIGITAL                                   3
#           57565220 PRÁTICAS DE LEITURA EM INGLÊS                            4
#           57565222 RESOLUÇÃO DE PROBLEMAS MATEMÁTICOS PARA TI               3
#           57565224 RESOLUÇÃO DE PROBLEMAS MATEMÁTICOS PARA TI               1
#           57568130 TÓPICOS ESPECIAIS EM TECNOLOGIA DA INFORMAÇÃO IV         1
#           57568131 TÓPICOS ESPECIAIS EM TECNOLOGIA DA INFORMAÇÃO V          2
#           57572025 PROTOCOLO E SERVIÇOS DE INTERNET                         1
#
# [762 rows x 2 columns]
